# %% [markdown]
# # Step 1: SNOMED Ground Truth Extraction (via BioPortal API)
#
# This notebook:
# 1. Validates each concept term against the BioPortal SNOMED CT API
# 2. Replaces NOT FOUND concepts with random valid SNOMED concepts
# 3. Extracts ground truth relationships (parents, grandparents, children, siblings)
# 4. Saves `validated_concepts.csv` and `ground_truth.csv`
#
# **Run this notebook ONCE** from the `ground_truth/` folder.
# The output is shared by all LLM testing folders (testing_gpt, testing_claude, etc.).
#
# After this, run `step2_llm_queries.ipynb` in each testing folder.

# %% [markdown]
# ## Configuration

# %%
import os
import re
import random
import requests
import time
from datetime import datetime
from pathlib import Path
from urllib.parse import quote

import pandas as pd

# ============================================================
# Path Configuration
# ============================================================

_cwd = Path(".").resolve()
# This notebook lives in ground_truth/ at repo root
if _cwd.name == "ground_truth":
    REPO_ROOT = _cwd.parent
else:
    REPO_ROOT = _cwd  # running from repo root

OUTPUT_ROOT = (REPO_ROOT / "output").resolve()
GT_ROOT = OUTPUT_ROOT / "ground_truth"
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
GT_ROOT.mkdir(parents=True, exist_ok=True)

# Output files (shared across all LLMs)
GT_OUT = GT_ROOT / "ground_truth.csv"
VALIDATED_CONCEPTS_OUT = GT_ROOT / "validated_concepts.csv"
LOG_DIR = GT_ROOT

# Set to True to run on 5 random concepts only (for testing)
TEST_MODE = False

print("Output directory:", GT_ROOT)
# Out:
# Output directory: /Users/narenkhatwani/Documents/GitHub/llm-as-ontology-server/output/ground_truth

# %% [markdown]
# ## Concept Terms

# %%
# Full list (same as in step1 / step2 / step3)
CONCEPT_TERMS = [
    "Acute myocardial infarction", "Atrial fibrillation", "Hypertensive disorder, systemic arterial", "Atherosclerosis",
    "Embolus", "Ventricular tachycardia", "Apnea", "Cyanosis", "Bronchitis", "Hyperglycemia", "Blood in urine", "Oliguria", "Polyuria", "Necrosis", "Ischemia", "Sepsis", "Malignant", "Benign", "Abscess", "Edema", "Intubation", "Biopsy", "Venipuncture", "Laparotomy", "Opening of chest", "Cholecystectomy", "Cardiopulmonary resuscitation", "Triage", "Proximal", "Distal", "Chronic", "Determination of prognosis", "Anaphylaxis", "Structure of ischiogluteal bursa of right hip", "Does not cut own nails", "Laceration of right brachial artery", "Date sample received in laboratory", "Autosomal recessive severe congenital neutropenia due to jagunal homolog 1 deficiency", "Product containing only ezetimibe and rosuvastatin", "Alpha>1< anti-trypsin isotype MZ", "2-dehydro-3-deoxy-L-pentonate aldolase", "Thiourea", "Protriptyline", "Use of sling suspension", "Insulin receptor defect", "Akinesis of basal anterior segment of left cardiac ventricle", "Bioterrorist attack",
    "Rickettsia australis", "Computed tomography 3 dimensional reconstruction", "Open reduction of fracture of tarsal bone without internal fixation", "Identification of antibody to red blood cell antigens from Colton system (International Society of Blood Transfusion 015)", "Spirometra houghtonii", "Difficulty preparing feed", "Public school", "Assistive electrical shaver adaptor", "Bathing of skin of free upper limb", "Primary hyperparathyroidism", "Ultrasonography of soft tissue of wrist region", "Standing tolerance", "Product containing precisely alverine citrate 120 milligram/1 each conventional release oral capsule", "Structure of temporomandibular articulation vein", "Closed comminuted fracture of proximal phalanx of finger", "Choroidal retinal neovascularization", "Microunit/milliliter", "Unable to use a non-speech system for communication", "Chronic infective pericarditis", "Accidental poisoning caused by salicylates", "Product containing only nicotinic acid", "Dimethyl-ether propane", "Nipple sharing technique", "Accidental clorazepate poisoning", "Fetal disorder due to persistent occipito-posterior malposition during labor", "Carnitine acylcarnitine translocase deficiency", "Revision of gastrojejunal anastomosis with reconstruction with partial gastrectomy", "Abnormal radial pulse", "Accident due to heat in drying room", "Disease caused by Trichinelloidea", "Cervical anterior longitudinal ligament sprain", "Entire costal groove of eighth rib", "Myxopapillary ependymoma of brain",
    "Repositioning of cardioverter/defibrillator leads", "Buttiauxella brennerae", "Position of testicle", "Accidental lomustine poisoning", "Hemangioma of retina of bilateral eyes", "Mandelate racemase", "Structure of rhomboideus thoracis muscle", "Unable to move from lying to sitting", "Contact lens inserter/remover", "Cytosine deaminase", "Atrolysin F", "Entire pupillary margin of iris", "Compression hosiery class II below knee stocking flatbed knit made to measure", "Entire small subcutaneous vein", "Operation on pharynx", "Fluoroscopic angiography of dialysis fistula using contrast with insertion of stent graft", "Product containing only methotrexate", "Wart clinic", "Hemoglobin Dagestan", "Substance", "Family Chlorobiaceae", "Structure of pedicle of axis", "Bone structure of L4", "Lasègue's arm sign", "Neuroendocrine tumor of middle ear", "Extension Namespace {1000194}", "Fracture of third rib", "Overriding tricuspid valve", "Cerebellar laceration with open intracranial wound", "Sacral spinal cord injury without bone injury", "Dehydrated hereditary stomatocytosis", "Product containing precisely tinzaparin sodium 20000 unit/1 milliliter conventional release solution for injection", "History of mood disorder", "Dislocation of prosthetic joint of elbow", "Product containing only brompheniramine and guaifenesin and hydrocodone in oral dose form", "Unable to wash laundry", "Entire corticothalamic fibers of posterior limb of internal capsule", "Product containing precisely lidocaine hydrochloride 1 milligram/1 milliliter conventional release solution for injection",
    "Congenital absence of uvula", "Streptococcus pyogenes type emm35", "Fracture of mandible involving dental socket", "Foreign body in skin of finger with infection", "Product containing precisely naloxone hydrochloride 400 microgram/1 milliliter conventional release solution for injection", "Excisional biopsy of lacrimal sac", "Catatonic posturing", "Structure of palmaris brevis muscle", "Butteroil", "Entire ventral posterolateral nucleus of thalamus", "Anomalous pulmonary venous drainage to right atrium", "Caries of cervical margin of tooth", "Bursitis of shoulder", "Laboratory oven", "Assessment using physical function intensive care unit test", "Oral dyskinesia", "Family Ranidae", "Acute postthoracotomy pain syndrome", "Trapezius flap", "Fetal movements palpated by healthcare professional", "Product containing only sodium thiosulfate in parenteral dose form", "Zamia", "Provision of removable artificial eye", "Hypokinesis of myocardium of anterolateral region of left ventricle", "CV20", "Primary malignant neoplasm of intrathoracic organs", "Salmonella IIIb 38:(k):z54", "Purpura simplex", "Arsine poisoning", "Continuous flow apneic ventilation", "Extension Namespace {1000164}", "Ear and auditory finding", "Antibody to myelin associated glycoprotein", "Genus Cercocebus", "Urge incontinence due to prolapse of female genital organ", "Streptococcus pyogenes type emm111", "Partial glossectomy with radical dissection of left half of neck", "Paenibacillus doosanensis", "Diapterus auratus", "Ribonucleic acid of Parainfluenza virus 4", "Cryptocotyle concava", "Calicivirus gastroenteritis", "Acute sensory polyneuropathy", "Sabouraud dextrose agar", "Urrets-Zavalia syndrome of eye due to and following ocular surgery",
    "Product containing only flortaucipir (18-F) in parenteral dose form", "Structure of skin of left knee", "Grafting of auricle of ear", "Closed fracture of fifth metatarsal bone of right foot", "Ultrasonic wave", "Accessory mobilization of the cervical spine", "Scilla nonscripta", "Product containing precisely mepacrine hydrochloride 100 milligram/1 each conventional release oral tablet", "Antibiotic sensitivity, fungus", "Alcohol, methyl measurement", "Structure of bursa of thumb", "History and physical examination, sports participation", "Haemophilus felis", "Cholylglycine measurement", "Radiation half-value thickness", "Entire embryo at stage 15", "Product containing only mecobalamin", "Genus Lophodytes", "Mycoplasma hyopneumoniae", "Fetal chromosomal abnormality", "History of cancer metastatic to bone", "Orthopedic fixation plate, non-bioabsorbable, non-sterile", "Neoplasm of isthmus of uterus", "Urethrotome", "Death by immolation", "Skin of part of back", "Croton oil", "Associated_finding_filler", "Lyssavirus aravan", "Main spoken language Esperanto", "Unable to prepare food hygienically", "Proximal radioulnar joint structure", "Early onset cerebellar ataxia", "Cresylglycidyl ether", "Etheostoma zoniferum", "Plasma thawing unit", "Fracture of coccyx", "3 o'clock position on mammogram", "Old posterior cruciate ligament disruption", "Anxious avoidant attachment", "Inflammation of left iliohypogastric nerve", "Re-excision of breast for clearance of tumor margins", "Diamond dental laboratory bur", "Family Fuselloviridae", "Occlusion of vein of corpus cavernosum of penis", "Autosomal dominant intermediate Charcot-Marie-Tooth disease type C", "Hemoglobin Volga", "Punctate outer retinal toxoplasmosis", "Congenital talipes calcaneovalgus", "Recurrent acute streptococcal tonsillitis",
    "Jaeger type 10", "Myofascial pain syndrome of lower back", "Spine dislocation due to birth trauma", "Netta rufina", "Congenital abnormality of systemic vein", "Stachybotrys chartarum", "Fracture of phalanx of finger of left hand", "Astroscopus y-graecum", "Vaccine product containing only Clostridium tetani and Human poliovirus antigens", "Single photon emission computed tomography system", "Measurement of Influenza A virus antibody and Influenza B virus antibody", "Chronic radiation nephritis", "Giant retinal tear", "Structure of lateral surface of upper arm", "Family Echinorhynchidae", "Embolectomy with catheter of celiac artery by abdominal incision", "Entire zygomatic arch", "Application of hot water bottle", "Tilmicosin", "Hypothalamic releasing factor", "Perioral numbness", "Electron microscopy study, transmission, examination and report", "Structure of hypothalamicohypophyseal tract", "Incision and exploration of tunica vaginalis", "Injury of nasopharynx", "Grafting of fascia to tarsal cartilage", "Accidental ingestion of spurge olive berries", "Stimulus response inventory", "Fall risk assessment declined", "Vegetable suet", "Flexion deformity of joint of right ankle", "Delayed allogeneic transplantation, living donor", "Finding of knee joint color", "Entire sinus venosus of fetus", "Blood (white blood cell) screen for GM1 gangliosidosis", "Cystic testicular dysplasia", "No active range of shoulder circumduction", "Product containing precisely promethazine hydrochloride 25 milligram/1 each conventional release oral tablet", "Spotted creeper", "Chilomastix intestinalis", "Extraprostatic extension of tumor present, non-focal", "Arteriovenous graft rupture", "Structure of superficial anterior cervical lymph node", "Myelodysplastic syndrome with excess blasts-1", "Administration of substance via buccal route",
    "Product containing only bendroflumethiazide and potassium chloride", "Transmission-based precautions", "Tooth disorder", "Physical", "Dislocation of ear ossicles", "Fracture dislocation of symphysis pubis", "Tache noire of sclera of left eye", "Volatile inhalant dependence, episodic", "Decreased N-3 fatty acid diet", "Carbapenemase-producing Lelliottia amnigena", "Polychromatophilic erythroblast", "Fuller's earth dust", "Stress fracture of sacrum", "Poor self-esteem", "Bathrocephaly", "Snuff user", "Generalized onset motor epileptic seizure", "Allergy treatment changed", "Erosion of pacemaker pocket due to and following implantation of cardiac pacemaker", "Head lifting exercise", "Entire corpus penis", "Oligopus diagrammus", "Deficiency of ribose-5-phosphate isomerase", "Progestogen overdose", "Cartilage graft - prominent ear", "Borrelia theileri", "Mood disorder with mixed depressive and manic symptoms caused by volatile inhalant", "Degloving injury buttock", "Attachment of bone anchored hearing prosthesis", "Air traffic controller", "Entire intervertebral symphysis between T2 and T3", "Protostrongylus brevispiculum", "Vasomotor rhinitis", "Able to open and close mouth", "Pseudoxanthomonas helianthi", "Repair of ventral hernia using graft", "Assessment using Short Form of the Informant Questionnaire on Cognitive Decline in the Elderly", "Acute inflammation", "Autosomal recessive hereditary spastic paraplegia", "Octomitus", "Toxoplasma tubulointerstitial nephropathy", "Notropis harperi", "History of toxoplasmosis", "Blood group antigen Sk^a^", "Wedge excision of skin of nail fold", "Finding of difference in location compared to previous radiologic examination", "Christo Inventory for Substance-misuse Services total score", "Aspidites melanocephalus", "General medical self-referral", "Artery of extremity transposition", "Occlusion of left central retinal artery",
    "Nutrient absorption inhibitor", "Laceration of thigh without foreign body", "Eimeria magna", "Enterocolic fistula", "Rehabilitation care plan", "Blood group antigen Naz", "Bilastine", "Appearance of oral mucosa", "Superior closed dislocation", "Khoshamian", "Urine codeine measurement", "Computed tomography of thigh for radiotherapy planning", "Application of long leg cast", "Acute duodenitis", "Nuclear medicine system table, powered", "Local tumor spread", "Family Kogiidae", "Able to transfer from wheelchair to chair", "Selectron therapy", "Structure of superficial part of superior levator palpebrae muscle", "Entire left wall of urinary bladder", "Urine specimen care assessment", "Structure of intervertebral disc of sacral vertebra", "Amino acids peritoneal dialysis solution", "Family Caryophyllaceae", "Umbilical catheter submitted as specimen", "Product containing precisely desmopressin acetate 100 microgram/1 milliliter conventional release nasal solution", "Syncytial cell", "Extension Namespace {1000085}", "Congenital absence of frontal bone", "Incision and exploration of rectum", "Needle catheter", "Percutaneous transluminal embolization of femoral artery", "Stung by cone shell", "Head artery injection", "True insight, function", "Disorder due to and following injury of muscle and tendon of upper limb", "Entire left foot", "Recurrent erosion of cornea of left eye", "Excision of salivary gland", "Adverse effect of prosthetic device", "Total excision of meningioma", "Cote d'Ivoire", "Fluoroscopic venography of hepatic vein with contrast and insertion of stent graft", "Amyloid deposition", "Measurement of serum thyroid stimulating hormone", "Excessive secretin secretion", "Cataract lens fragments in vitreous of left eye due to and following cataract surgery", "Toe joint crepitus", "Gynecological operating table", "Product containing hydrolase inhibitor", "Edoxaban tosylate", "Deep dog bite", "Family Kinosternidae",
    "Substance with sodium/potassium adenosine triphosphatase enzyme inhibitor mechanism of action", "Delayed suture of tendon", "Specimen source",
    "Microinvasive carcinoma", "Abdominal reflex delayed", "Product containing only phenazopyridine", "Incision and drainage of hematoma", "Skin structure of infratemporal region", "Soft tissue lesion of foot region", "Arthroscopic release of capsule of hip joint", "Traumatic joint hemarthrosis", "Long QT syndrome caused by drug", "Neocoger mucronatus", "Product containing bismuth subsalicylate and metronidazole and tetracycline", "Pulmonary artery pressure", "Arthroscopy of shoulder with complete synovectomy", "beta-Aminoisobutyrate measurement", "Injury of thymus gland", "Finding related to ability to balance", "Porphyrins, quantitation and fractionation, urine", "Trichostrongylus retortaeformis", "Extrinsic motivation", "Duodenal candidosis", "Take impression for lower removable orthodontic appliance", "Primary basal cell carcinoma of skin of left foot", "Rigid ankle-foot orthosis", "Closed fracture thumb proximal phalanx, head", "Acute suppuration of maxillary sinus", "Dodecenoyl-coenzyme A delta-isomerase", "Entire lymphatic vessel of orbit", "Blood group antigen Wallin", "Corynebacterium species not Corynebacterium jeikeium", "Nocardioides terrae", "Lactobacillus rhamnosus GG", "Pain of breast", "Structure of left cochlear", "Decreased active range of hip flexion"
]

print(f"Full list: {len(CONCEPT_TERMS)} concepts")
# Out:
# Full list: 400 concepts

# %%
if TEST_MODE:
    import random as _rng
    _rng.seed(42)
    CONCEPT_TERMS = _rng.sample(CONCEPT_TERMS, min(5, len(CONCEPT_TERMS)))
    print(f"TEST MODE: using {len(CONCEPT_TERMS)} random concepts")
print(f"Concepts to process: {len(CONCEPT_TERMS)}")
# Out:
# Concepts to process: 400

# %% [markdown]
# ## Backup Concepts
#
# Known-good SNOMED CT concepts used as replacements when a primary concept is NOT FOUND.

# %%
BACKUP_CONCEPTS = [
    "Diabetes mellitus",
    "Asthma",
    "Pneumonia",
    "Fracture of femur",
    "Appendectomy",
    "Aspirin allergy",
    "Migraine",
    "Osteoarthritis",
    "Chronic kidney disease",
    "Hypothyroidism",
    "Rheumatoid arthritis",
    "Epilepsy",
    "Pulmonary embolism",
    "Cellulitis",
    "Otitis media",
    "Cirrhosis of liver",
    "Gout",
    "Psoriasis",
    "Endoscopy",
    "Electrocardiogram",
    "Colonoscopy",
    "Tonsillectomy",
    "Blood glucose measurement",
    "Platelet count",
    "Hemoglobin A1c measurement",
    "Cerebrovascular accident",
    "Deep vein thrombosis",
    "Congestive heart failure",
    "Chronic obstructive lung disease",
    "Peptic ulcer",
]

# Remove any backup concepts that are already in the primary list
BACKUP_CONCEPTS = [c for c in BACKUP_CONCEPTS if c not in set(CONCEPT_TERMS)]
random.shuffle(BACKUP_CONCEPTS)
print(f"Primary concepts: {len(CONCEPT_TERMS)}, Backup pool: {len(BACKUP_CONCEPTS)}")
# Out:
# Primary concepts: 400, Backup pool: 30

# %% [markdown]
# ## BioPortal API Setup
#
# Configure API access and define helper functions for SNOMED CT queries.

# %%
LOG_PATH = LOG_DIR / "logs.txt"

# ============================================================
# BioPortal API configuration
# ============================================================
BIOPORTAL_BASE = "https://data.bioontology.org"
ONTOLOGY = "SNOMEDCT"

# Option 1: Set via environment variable (recommended)
# Option 2: Paste your key directly below if env var is not picked up
BIOPORTAL_API_KEY = os.environ.get("BIOPORTAL_API_KEY", "")

# Uncomment and paste your key here if the environment variable is not detected:
BIOPORTAL_API_KEY = "7d367420-b0d2-4646-aa43-90fd76bd47ed"

if not BIOPORTAL_API_KEY:
    raise EnvironmentError(
        "BIOPORTAL_API_KEY is not set. Either:\n"
        "  1. export BIOPORTAL_API_KEY='your-key' in your shell and restart the kernel, or\n"
        "  2. Paste your key directly in the cell above (uncomment the line)."
    )

API_DELAY = 0.5   # seconds between API calls
API_TIMEOUT = 30   # seconds per request
MAX_RETRIES = 2    # retry on transient failures

_api_cache = {}
_api_call_count = 0


def _class_uri(concept_id: str) -> str:
    """Build the BioPortal class URI for a SNOMED CT concept."""
    return f"http://purl.bioontology.org/ontology/SNOMEDCT/{concept_id}"


def _encode_uri(uri: str) -> str:
    """URL-encode a class URI for use in BioPortal path segments."""
    return quote(uri, safe="")


def _extract_concept_id(class_id: str) -> str:
    """Extract the SNOMED concept ID from a BioPortal class @id URI."""
    if "/" in class_id:
        return class_id.rsplit("/", 1)[-1]
    return class_id


def _api_get(url, params=None, timeout=None):
    """GET with caching, rate-limiting, and retry logic."""
    global _api_call_count
    cache_key = url + str(sorted((params or {}).items()))
    if cache_key in _api_cache:
        return _api_cache[cache_key]

    timeout = timeout or API_TIMEOUT

    if params is None:
        params = {}
    params.setdefault("apikey", BIOPORTAL_API_KEY)
    params.setdefault("display_links", "false")
    params.setdefault("display_context", "false")

    for attempt in range(MAX_RETRIES + 1):
        try:
            time.sleep(API_DELAY)
            resp = requests.get(url, params=params, timeout=timeout)
            resp.raise_for_status()
            data = resp.json()
            _api_cache[cache_key] = data
            _api_call_count += 1
            if _api_call_count % 20 == 0:
                print(f"  [{_api_call_count} API calls so far]")
            return data
        except requests.exceptions.Timeout as e:
            if attempt < MAX_RETRIES:
                wait = (attempt + 1) * 3
                print(f"    Timeout, retry {attempt+1}/{MAX_RETRIES} in {wait}s...")
                time.sleep(wait)
            else:
                raise
        except requests.exceptions.RequestException as e:
            if attempt < MAX_RETRIES:
                wait = (attempt + 1) * 3
                print(f"    Error: {e}, retry {attempt+1}/{MAX_RETRIES} in {wait}s...")
                time.sleep(wait)
            else:
                raise


def _csv_safe(x):
    if x is None:
        return ""
    return str(x).replace("\r", " ").replace("\n", " ").strip()


def list_to_pipe(items):
    """Convert a list of strings to pipe-separated string. No truncation."""
    items = [str(i).replace("|", " ").strip() for i in (items or []) if str(i).strip()]
    return "|".join(items)


def semantic_tag_from_fsn(fsn: str) -> str:
    m = re.search(r"\(([^()]*)\)\s*$", fsn or "")
    return m.group(1).strip() if m else "UNKNOWN"


# ============================================================
# SNOMED CT query functions
# ============================================================

def search_concept(term: str, exact=True):
    """Search for a concept by term.
    Returns (concept_id, prefLabel) or None.
    If exact=False, uses partial matching."""
    url = f"{BIOPORTAL_BASE}/search"
    params = {
        "q": term,
        "ontologies": ONTOLOGY,
        "pagesize": "10",
    }
    if exact:
        params["require_exact_match"] = "true"
    data = _api_get(url, params=params)
    for item in data.get("collection", []):
        if item.get("obsolete"):
            continue
        class_id = item.get("@id", "")
        pref_label = item.get("prefLabel", "")
        cid = _extract_concept_id(class_id)
        if cid:
            return cid, pref_label
    return None


def get_class_info(cid: str):
    """Get class info including FSN and definition status.
    Returns (fsn, definition_status).
    The FSN (Fully Specified Name) includes the semantic tag, e.g.
    'Selectron therapy (procedure)'. BioPortal's prefLabel returns
    the Preferred Term (no semantic tag), so we look through synonyms
    for the FSN which ends with '(tag)'."""
    try:
        encoded = _encode_uri(_class_uri(cid))
        url = f"{BIOPORTAL_BASE}/ontologies/{ONTOLOGY}/classes/{encoded}"
        data = _api_get(url, params={"include": "prefLabel,synonym,properties"})
        pref_label = data.get("prefLabel", "")
        synonyms = data.get("synonym", []) or []

        # --- Find the FSN (the synonym ending with a semantic tag in parens) ---
        fsn = pref_label  # fallback
        # Check if prefLabel itself already has the semantic tag
        if re.search(r"\([^()]+\)\s*$", pref_label):
            fsn = pref_label
        else:
            # Search through synonyms for one that ends with (semantic_tag)
            for syn in synonyms:
                if isinstance(syn, str) and re.search(r"\([^()]+\)\s*$", syn):
                    fsn = syn
                    break

        # --- Extract definition status ---
        props = data.get("properties", {})
        def_status_id = ""
        # Search through all property keys for definition status
        # BioPortal may use different key formats:
        #   - 'definitionStatusId'
        #   - 'DEFINITION_STATUS_ID'
        #   - URI like 'http://snomed.info/.../definitionStatusId'
        for key, val in props.items():
            key_lower = key.lower()
            if "definitionstatus" in key_lower or "definition_status" in key_lower:
                def_status_id = val[0] if isinstance(val, list) and val else str(val)
                break
        # Debug: log property keys for the first few concepts
        if _api_call_count <= 5:
            prop_keys = [k.rsplit('/', 1)[-1] if '/' in k else k for k in props.keys()]
            print(f"    [debug] properties keys for {cid}: {prop_keys}")
            if def_status_id:
                print(f"    [debug] definition_status raw value: {def_status_id}")
        if "900000000000073002" in def_status_id:
            def_status = "Fully defined"
        elif "900000000000074008" in def_status_id:
            def_status = "Primitive"
        else:
            # Try to interpret the value itself
            val_lower = def_status_id.lower()
            if "defined" in val_lower:
                def_status = "Fully defined"
            elif "primitive" in val_lower:
                def_status = "Primitive"
            else:
                def_status = "UNKNOWN"
        return fsn, def_status
    except Exception as e:
        print(f"    WARNING: get_class_info({cid}) failed: {e}")
        return "", "UNKNOWN"


def get_parents(cid: str):
    """Get parents. Returns list of (concept_id, prefLabel) tuples."""
    try:
        encoded = _encode_uri(_class_uri(cid))
        url = f"{BIOPORTAL_BASE}/ontologies/{ONTOLOGY}/classes/{encoded}/parents"
        data = _api_get(url)
        results = []
        if isinstance(data, list):
            items = data
        else:
            items = data.get("collection", data.get("results", []))
        for item in items:
            pid = _extract_concept_id(item.get("@id", ""))
            pref = item.get("prefLabel", "")
            if pid:
                results.append((pid, pref))
        return results
    except Exception as e:
        print(f"    WARNING: get_parents({cid}) failed: {e}")
        return []


def get_children(cid: str):
    """Get children. Returns list of (concept_id, prefLabel) tuples."""
    try:
        encoded = _encode_uri(_class_uri(cid))
        url = f"{BIOPORTAL_BASE}/ontologies/{ONTOLOGY}/classes/{encoded}/children"
        data = _api_get(url, params={"pagesize": "100"}, timeout=20)
        results = []
        items = data.get("collection", []) if isinstance(data, dict) else data
        for item in items:
            child_id = _extract_concept_id(item.get("@id", ""))
            pref = item.get("prefLabel", "")
            if child_id:
                results.append((child_id, pref))
        return results
    except requests.exceptions.Timeout:
        print(f"    (children timeout for {cid} - likely a leaf concept)")
        return []
    except Exception as e:
        print(f"    WARNING: get_children({cid}) failed: {e}")
        return []


def get_siblings(cid: str):
    """Get siblings (share a parent). Returns list of prefLabel strings."""
    sibs = set()
    for pid, _ in get_parents(cid):
        for child_id, child_pref in get_children(pid):
            if child_id != cid:
                sibs.add(child_pref)
    return list(sibs)


def get_grandparents(cid: str):
    """Get grandparents (parents of parents, depth -2). Returns list of prefLabel strings."""
    gps = set()
    for parent_id, _ in get_parents(cid):
        for gp_id, gp_pref in get_parents(parent_id):
            gps.add(gp_pref)
    return list(gps)


print("BioPortal API configured.")
print(f"API base: {BIOPORTAL_BASE}")
print(f"Ontology: {ONTOLOGY}")
# Out:
# BioPortal API configured.
# API base: https://data.bioontology.org
# Ontology: SNOMEDCT

# %% [markdown]
# ## Concept Validation & Ground Truth Extraction
#
# For each concept:
# 1. Try exact match in BioPortal
# 2. If not found, try partial/fuzzy match
# 3. If still not found, replace with a concept from the backup pool
# 4. Extract ground truth relationships
#
# **Resume:** If you interrupt and re-run this cell, it loads existing
# `ground_truth.csv` and `validated_concepts.csv`, skips concepts already done,
# and continues from the next concept. Progress is saved every 10 concepts.

# %%
# ============================================================
# Validate concepts and extract ground truth
# ============================================================

backup_idx = 0
gt_rows = []
validation_rows = []
not_found_terms = []
replaced_terms = []

# ---- Resume: load existing progress if present ----
already_processed = set()
if VALIDATED_CONCEPTS_OUT.exists():
    _val = pd.read_csv(VALIDATED_CONCEPTS_OUT)
    already_processed = set(_val["original_term"].dropna().astype(str).str.strip())
    validation_rows = _val.to_dict("records")
    validation_rows = [{"concept_term": r.get("concept_term", ""), "original_term": r.get("original_term", ""), "snomed_id": str(r.get("snomed_id", "")), "status": r.get("status", "")} for r in validation_rows]
    backup_idx = sum(1 for r in validation_rows if r.get("status") == "replaced")
if GT_OUT.exists():
    _gt = pd.read_csv(GT_OUT)
    gt_rows = _gt.to_dict("records")
    gt_rows = [{k: ("" if pd.isna(v) else str(v)) for k, v in row.items()} for row in gt_rows]

concepts_to_process = [c for c in CONCEPT_TERMS if c not in already_processed]

if already_processed:
    print(f"Resuming: {len(already_processed)} concepts already done, {len(concepts_to_process)} remaining.")
print(f"Validating and extracting GT for {len(concepts_to_process)} concepts...")
print(f"Backup pool: {len(BACKUP_CONCEPTS)} concepts available (consumed so far: {backup_idx})\n")

for i, concept_term in enumerate(concepts_to_process):
    original_term = concept_term
    status = "found"

    try:
        # Step 1: Try exact match
        result = search_concept(concept_term, exact=True)

        # Step 2: Try partial match if exact fails
        if result is None:
            result = search_concept(concept_term, exact=False)
            if result:
                status = "partial_match"
                print(f"  [{i+1}/{len(concepts_to_process)}] {concept_term} -> partial match: {result[1]}")

        # Step 3: Replace with backup concept if still not found
        if result is None:
            not_found_terms.append(concept_term)
            # Try backup concepts until we find one that works
            replacement_found = False
            while backup_idx < len(BACKUP_CONCEPTS):
                backup_term = BACKUP_CONCEPTS[backup_idx]
                backup_idx += 1
                backup_result = search_concept(backup_term, exact=True)
                if backup_result is None:
                    backup_result = search_concept(backup_term, exact=False)
                if backup_result:
                    result = backup_result
                    concept_term = backup_term
                    status = "replaced"
                    replaced_terms.append((original_term, backup_term))
                    print(f"  [{i+1}/{len(concepts_to_process)}] {original_term} -> NOT FOUND, replaced with: {backup_term} ({result[0]})")
                    replacement_found = True
                    break
            if not replacement_found:
                print(f"  [{i+1}/{len(concepts_to_process)}] {original_term} -> NOT FOUND (no backup available)")
                validation_rows.append({
                    "concept_term": original_term,
                    "original_term": original_term,
                    "snomed_id": "",
                    "status": "not_found",
                })
                with LOG_PATH.open("a") as f:
                    f.write(f"{datetime.now().isoformat()}\t{original_term}\tNOT_FOUND\n")
                continue

        cid, pref_label = result

        # Extract ground truth
        fsn, def_status = get_class_info(cid)
        if not fsn:
            fsn = pref_label  # fallback to search prefLabel
        sem_tag = semantic_tag_from_fsn(fsn)

        parent_tuples = get_parents(cid)
        child_tuples = get_children(cid)
        parent_labels = [lbl for _, lbl in parent_tuples]
        child_labels = [lbl for _, lbl in child_tuples]
        sib_labels = get_siblings(cid)
        gp_labels = get_grandparents(cid)

        gt_rows.append({
            "timestamp": datetime.now().isoformat(),
            "concept_term": concept_term,
            "snomed_id": cid,
            "fsn": _csv_safe(fsn),
            "semantic_tag": _csv_safe(sem_tag),
            "definition_status": _csv_safe(def_status),
            "parents": list_to_pipe(parent_labels),
            "grandparents": list_to_pipe(gp_labels),
            "children": list_to_pipe(child_labels),
            "siblings": list_to_pipe(sib_labels),
        })

        validation_rows.append({
            "concept_term": concept_term,
            "original_term": original_term,
            "snomed_id": cid,
            "status": status,
        })

        if status == "found":
            print(f"  [{i+1}/{len(concepts_to_process)}] {concept_term} -> {cid} "
                  f"({len(parent_labels)}P, {len(gp_labels)}GP, {len(child_labels)}C, {len(sib_labels)}S)")

        with LOG_PATH.open("a") as f:
            f.write(
                "\n" + "=" * 80 + "\n" + datetime.now().isoformat() + "\n"
                + f"CONCEPT: {concept_term} (original: {original_term})\n"
                + f"STATUS: {status}\n"
                + f"SNOMED_ID: {cid}\nFSN: {fsn}\n"
                + f"TAG: {sem_tag}\nDEF_STATUS: {def_status}\n"
                + f"PARENTS: {parent_labels}\nGRANDPARENTS: {gp_labels}\n"
                + f"CHILDREN: {child_labels}\nSIBLINGS ({len(sib_labels)}): {sib_labels[:10]}...\n"
            )

    except Exception as e:
        with LOG_PATH.open("a") as f:
            f.write(f"{datetime.now().isoformat()}\t{original_term}\tERROR\t{e}\n")
        print(f"  [{i+1}/{len(concepts_to_process)}] {original_term} -> ERROR: {e}")

    # --- Incremental save every 10 concepts ---
    if gt_rows and (i + 1) % 10 == 0:
        _tmp_gt = pd.DataFrame(gt_rows)
        _tmp_gt = _tmp_gt[[
            "timestamp", "concept_term", "snomed_id",
            "fsn", "semantic_tag", "definition_status",
            "parents", "grandparents", "children", "siblings",
        ]]
        _tmp_gt.to_csv(GT_OUT, index=False)
        _tmp_val = pd.DataFrame(validation_rows)
        if not _tmp_val.empty:
            _tmp_val[["concept_term", "original_term", "snomed_id", "status"]].to_csv(VALIDATED_CONCEPTS_OUT, index=False)
        print(f"    [checkpoint] Saved {len(gt_rows)} concepts to CSV")

print(f"\nDone. Total API calls: {_api_call_count}")
print(f"Found: {sum(1 for r in validation_rows if r['status'] == 'found')}")
print(f"Partial match: {sum(1 for r in validation_rows if r['status'] == 'partial_match')}")
print(f"Replaced: {sum(1 for r in validation_rows if r['status'] == 'replaced')}")
print(f"Not found (no replacement): {sum(1 for r in validation_rows if r['status'] == 'not_found')}")
# Out:
# Validating and extracting GT for 400 concepts...
# Backup pool: 30 concepts available (consumed so far: 0)
#
#     [debug] properties keys for 57054005: ['TYPE_ID', 'CASE_SIGNIFICANCE_ID', 'core#notation', 'core#altLabel', 'EFFECTIVE_TIME', 'ACTIVE', 'has_finding_site', 'has_clinical_course', 'core#prefLabel', 'rdf-schema#subClassOf', 'hasSTY', 'cause_of', '22-rdf-syntax-ns#type', 'SUBSET_MEMBER', 'DEFINITION_STATUS_ID', 'tui', 'CTV3ID', 'cui', 'occurs_before', 'has_associated_morphology']
#     [debug] definition_status raw value: 900000000000073002
#   [1/400] Acute myocardial infarction -> 57054005 (2P, 3GP, 19C, 18S)
#   [2/400] Atrial fibrillation -> 49436004 (3P, 4GP, 12C, 13S)
#   [20 API calls so far]
#   [3/400] Hypertensive disorder, systemic arterial -> 38341003 (2P, 2GP, 27C, 66S)
#   [4/400] Atherosclerosis -> 38716007 (1P, 1GP, 0C, 0S)
#   [5/400] Embolus -> 55584005 (1P, 2GP, 23C, 51S)
#   [40 API calls so far]
#   [6/400] Ventricular tachycardia -> 25569003 (2P, 4GP, 24C, 38S)
#   [7/400] Apnea -> 1023001 (1P, 2GP, 16C, 3S)
#   [60 API calls so far]
#   [8/400] Cyanosis -> 3415004 (2P, 2GP, 7C, 48S)
#   [9/400] Bronchitis -> 32398004 (3P, 7GP, 19C, 131S)
#   [10/400] Hyperglycemia -> 80394007 (1P, 1GP, 10C, 2S)
#     [checkpoint] Saved 10 concepts to CSV
#   [80 API calls so far]
#   [11/400] Blood in urine -> 34436003 (1P, 1GP, 3C, 36S)
#   [12/400] Oliguria -> 83128009 (1P, 3GP, 6C, 3S)
#   [13/400] Polyuria -> 28442001 (2P, 1GP, 3C, 54S)
#   [100 API calls so far]
#   [14/400] Necrosis -> 6574001 (1P, 1GP, 34C, 29S)
#   [15/400] Ischemia -> 52674009 (2P, 2GP, 20C, 25S)
#   [16/400] Sepsis -> 91302008 (3P, 2GP, 55C, 156S)
#   [120 API calls so far]
#   [17/400] Malignant -> 21594007 (2P, 2GP, 0C, 174S)
#   [18/400] Benign -> 30807003 (1P, 1GP, 0C, 100S)
#   [19/400] Abscess -> 128477000 (1P, 1GP, 39C, 100S)
#   [140 API calls so far]
#   [20/400] Edema -> 267038008 (1P, 0GP, 29C, 99S)
#     [checkpoint] Saved 20 concepts to CSV
#   [21/400] Intubation -> 52765003 (2P, 2GP, 7C, 72S)
#   [22/400] Biopsy -> 86273004 (1P, 1GP, 39C, 89S)
#   [160 API calls so far]
#   [23/400] Venipuncture -> 22778000 (2P, 2GP, 4C, 47S)
#   [24/400] Laparotomy -> 86481000 (2P, 2GP, 16C, 63S)
#   [25/400] Opening of chest -> 177765008 (1P, 2GP, 7C, 44S)
#   [180 API calls so far]
#   [26/400] Cholecystectomy -> 38102005 (2P, 3GP, 8C, 18S)
#   [27/400] Cardiopulmonary resuscitation -> 89666000 (2P, 3GP, 3C, 6S)
#   [28/400] Triage -> 225390008 (1P, 1GP, 3C, 99S)
#   [200 API calls so far]
#   [29/400] Proximal -> 40415009 (2P, 2GP, 0C, 121S)
#   [30/400] Distal -> 46053002 (2P, 2GP, 0C, 121S)
#     [checkpoint] Saved 30 concepts to CSV
#   [31/400] Chronic -> 90734009 (1P, 2GP, 10C, 9S)
#   [220 API calls so far]
#   [32/400] Determination of prognosis -> 20481000 (1P, 1GP, 0C, 99S)
#   [33/400] Anaphylaxis -> 39579001 (2P, 3GP, 20C, 29S)
#   [34/400] Structure of ischiogluteal bursa of right hip -> 722754002 (3P, 5GP, 0C, 10S)
#   [240 API calls so far]
#   [35/400] Does not cut own nails -> 284873008 (2P, 2GP, 2C, 6S)
#   [36/400] Laceration of right brachial artery -> 11816061000119107 (3P, 5GP, 0C, 198S)
#   [260 API calls so far]
#   [37/400] Date sample received in laboratory -> 281271004 (1P, 1GP, 0C, 55S)
#   [38/400] Autosomal recessive severe congenital neutropenia due to jagunal homolog 1 deficiency -> 783199003 (2P, 3GP, 0C, 114S)
#   [39/400] Product containing only ezetimibe and rosuvastatin -> partial match: Ezetimibe and rosuvastatin only product
#   [280 API calls so far]
#   [40/400] Alpha>1< anti-trypsin isotype MZ -> 102790009 (1P, 2GP, 0C, 4S)
#     [checkpoint] Saved 40 concepts to CSV
#   [41/400] 2-dehydro-3-deoxy-L-pentonate aldolase -> 51364000 (2P, 2GP, 0C, 187S)
#   [300 API calls so far]
#   [42/400] Thiourea -> 47826006 (4P, 5GP, 2C, 66S)
#   [43/400] Protriptyline -> 372760009 (2P, 3GP, 0C, 40S)
#   [44/400] Use of sling suspension -> 39317007 (1P, 1GP, 0C, 33S)
#   [320 API calls so far]
#   [45/400] Insulin receptor defect -> 10680005 (1P, 1GP, 3C, 1S)
#   [46/400] Akinesis of basal anterior segment of left cardiac ventricle -> partial match: Entire basal anterior segment of left cardiac ventricle
#   [47/400] Bioterrorist attack -> 409495001 (1P, 1GP, 0C, 0S)
#   [340 API calls so far]
#   [48/400] Rickettsia australis -> 53447008 (1P, 1GP, 0C, 13S)
#   [49/400] Computed tomography 3 dimensional reconstruction -> 22400007 (1P, 1GP, 1C, 39S)
#   [50/400] Open reduction of fracture of tarsal bone without internal fixation -> 699166007 (3P, 5GP, 2C, 53S)
#     [checkpoint] Saved 50 concepts to CSV
#   [360 API calls so far]
#   [51/400] Identification of antibody to red blood cell antigens from Colton system (International Society of Blood Transfusion 015) -> 104030003 (1P, 2GP, 0C, 36S)
#   [52/400] Spirometra houghtonii -> 112459002 (1P, 1GP, 0C, 7S)
#   [53/400] Difficulty preparing feed -> 286499006 (2P, 3GP, 0C, 10S)
#   [380 API calls so far]
#   [54/400] Public school -> 224858000 (1P, 1GP, 0C, 9S)
#   [55/400] Assistive electrical shaver adaptor -> 465026001 (1P, 1GP, 0C, 29S)
#   [56/400] Bathing of skin of free upper limb -> 1234843005 (2P, 3GP, 2C, 19S)
#   [400 API calls so far]
#   [57/400] Primary hyperparathyroidism -> 36348003 (1P, 2GP, 3C, 6S)
#   [58/400] Ultrasonography of soft tissue of wrist region -> partial match: Ultrasonography of soft tissue of craniofacial region
#   [59/400] Standing tolerance -> 311463005 (1P, 1GP, 0C, 0S)
#   [420 API calls so far]
#   [60/400] Product containing precisely alverine citrate 120 milligram/1 each conventional release oral capsule -> partial match: Alverine citrate 120 mg oral capsule
#     [checkpoint] Saved 60 concepts to CSV
#   [61/400] Structure of temporomandibular articulation vein -> 152612004 (1P, 2GP, 1C, 4S)
#   [440 API calls so far]
#   [62/400] Closed comminuted fracture of proximal phalanx of finger -> 1255277009 (2P, 3GP, 0C, 11S)
#   [63/400] Choroidal retinal neovascularization -> 75971007 (5P, 8GP, 14C, 188S)
#   [64/400] Microunit/milliliter -> 258952008 (1P, 1GP, 0C, 10S)
#   [460 API calls so far]
#   [65/400] Unable to use a non-speech system for communication -> 288594008 (2P, 2GP, 0C, 5S)
#   [66/400] Chronic infective pericarditis -> 233886008 (3P, 6GP, 0C, 100S)
#   [480 API calls so far]
#   [67/400] Accidental poisoning caused by salicylates -> 216471009 (2P, 3GP, 2C, 54S)
#   [68/400] Product containing only nicotinic acid -> partial match: Nicotinic receptor antagonist-containing product
#   [69/400] Dimethyl-ether propane -> 396030004 (1P, 1GP, 0C, 99S)
#   [500 API calls so far]
#   [70/400] Nipple sharing technique -> 261209007 (1P, 1GP, 0C, 99S)
#     [checkpoint] Saved 70 concepts to CSV
#   [71/400] Accidental clorazepate poisoning -> 1145076003 (2P, 3GP, 1C, 43S)
#   [72/400] Fetal disorder due to persistent occipito-posterior malposition during labor -> 1263632004 (1P, 2GP, 0C, 5S)
#   [520 API calls so far]
#   [73/400] Carnitine acylcarnitine translocase deficiency -> 238003000 (1P, 2GP, 0C, 7S)
#   [74/400] Revision of gastrojejunal anastomosis with reconstruction with partial gastrectomy -> 55718003 (1P, 2GP, 0C, 2S)
#   [75/400] Abnormal radial pulse -> 39435002 (1P, 2GP, 2C, 11S)
#   [540 API calls so far]
#   [76/400] Accident due to heat in drying room -> 217596003 (1P, 1GP, 0C, 4S)
#   [77/400] Disease caused by Trichinelloidea -> 105700009 (1P, 1GP, 6C, 24S)
#   [78/400] Cervical anterior longitudinal ligament sprain -> 209559008 (1P, 3GP, 0C, 2S)
#   [560 API calls so far]
#   [79/400] Entire costal groove of eighth rib -> 21696003 (2P, 2GP, 0C, 11S)
#   [80/400] Myxopapillary ependymoma of brain -> 1197306009 (3P, 5GP, 0C, 22S)
#     [checkpoint] Saved 80 concepts to CSV
#   [580 API calls so far]
#   [81/400] Repositioning of cardioverter/defibrillator leads -> 46634008 (4P, 2GP, 1C, 229S)
#   [82/400] Buttiauxella brennerae -> 416844002 (1P, 1GP, 0C, 6S)
#   [83/400] Position of testicle -> 249237009 (1P, 1GP, 0C, 2S)
#   [600 API calls so far]
#   [84/400] Accidental lomustine poisoning -> 290628005 (2P, 3GP, 1C, 102S)
#   [85/400] Hemangioma of retina of bilateral eyes -> 15710001000119105 (3P, 5GP, 0C, 0S)
#   [620 API calls so far]
#   [86/400] Mandelate racemase -> 73858007 (2P, 2GP, 0C, 189S)
#   [87/400] Structure of rhomboideus thoracis muscle -> 60160007 (1P, 2GP, 1C, 6S)
#   [88/400] Unable to move from lying to sitting -> 282931003 (2P, 2GP, 0C, 6S)
#   [640 API calls so far]
#   [89/400] Contact lens inserter/remover -> 705256002 (1P, 1GP, 3C, 2S)
#   [90/400] Cytosine deaminase -> 85784002 (2P, 2GP, 0C, 177S)
#     [checkpoint] Saved 90 concepts to CSV
#   [91/400] Atrolysin F -> 130723008 (2P, 2GP, 0C, 177S)
#   [92/400] Entire pupillary margin of iris -> 362514008 (1P, 2GP, 0C, 3S)
#   [660 API calls so far]
#   [93/400] Compression hosiery class II below knee stocking flatbed knit made to measure -> 401633000 (1P, 1GP, 0C, 19S)
#   [94/400] Entire small subcutaneous vein -> 10617000 (3P, 4GP, 0C, 4S)
#   [680 API calls so far]
#   [95/400] Operation on pharynx -> 23136006 (4P, 6GP, 16C, 77S)
#   [96/400] Fluoroscopic angiography of dialysis fistula using contrast with insertion of stent graft -> 434435000 (1P, 2GP, 0C, 1S)
#   [97/400] Product containing only methotrexate -> partial match: Methotrexate only product
#   [700 API calls so far]
#   [98/400] Wart clinic -> 275692008 (1P, 1GP, 0C, 99S)
#   [99/400] Hemoglobin Dagestan -> 28538001 (1P, 1GP, 0C, 99S)
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167?include=prefLabel%2Csynonym%2Cproperties&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 1/2 in 3s...
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167?include=prefLabel%2Csynonym%2Cproperties&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 2/2 in 6s...
#     WARNING: get_class_info(T167) failed: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167?include=prefLabel%2Csynonym%2Cproperties&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 1/2 in 3s...
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 2/2 in 6s...
#     WARNING: get_parents(T167) failed: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/children?pagesize=100&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 1/2 in 3s...
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/children?pagesize=100&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 2/2 in 6s...
#     WARNING: get_children(T167) failed: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/children?pagesize=100&apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 1/2 in 3s...
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 2/2 in 6s...
#     WARNING: get_parents(T167) failed: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 1/2 in 3s...
#     Error: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false, retry 2/2 in 6s...
#     WARNING: get_parents(T167) failed: 404 Client Error: Not Found for url: https://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2FT167/parents?apikey=7d367420-b0d2-4646-aa43-90fd76bd47ed&display_links=false&display_context=false
#   [100/400] Substance -> T167 (0P, 0GP, 0C, 0S)
#     [checkpoint] Saved 100 concepts to CSV
#   [101/400] Family Chlorobiaceae -> 414199005 (2P, 2GP, 5C, 1S)
#   [720 API calls so far]
#   [102/400] Structure of pedicle of axis -> 313345004 (2P, 4GP, 1C, 9S)
#   [103/400] Bone structure of L4 -> 11994002 (1P, 3GP, 7C, 14S)
#   [740 API calls so far]
#   [104/400] Lasègue's arm sign -> 111957005 (2P, 2GP, 0C, 137S)
#   [105/400] Neuroendocrine tumor of middle ear -> 717918002 (2P, 4GP, 0C, 25S)
#   [106/400] Extension Namespace {1000194} -> 717031005 (1P, 1GP, 0C, 99S)
#   [107/400] Fracture of third rib -> partial match: Fracture of rib
#   [760 API calls so far]
#   [108/400] Overriding tricuspid valve -> 253378006 (2P, 3GP, 1C, 28S)
#   [780 API calls so far]
#   [109/400] Cerebellar laceration with open intracranial wound -> 30858001 (2P, 3GP, 4C, 5S)
#   [110/400] Sacral spinal cord injury without bone injury -> 4260009 (6P, 13GP, 0C, 296S)
#     [checkpoint] Saved 110 concepts to CSV
#   [800 API calls so far]
#   [111/400] Dehydrated hereditary stomatocytosis -> 715526002 (4P, 4GP, 0C, 138S)
#   [112/400] Product containing precisely tinzaparin sodium 20000 unit/1 milliliter conventional release solution for injection -> partial match: Tinzaparin sodium 20000 unit/mL solution for injection
#   [820 API calls so far]
#   [113/400] History of mood disorder -> 429124005 (1P, 1GP, 2C, 12S)
#   [114/400] Dislocation of prosthetic joint of elbow -> 1303208006 (5P, 10GP, 2C, 51S)
#   [115/400] Product containing only brompheniramine and guaifenesin and hydrocodone in oral dose form -> partial match: Brompheniramine and guaifenesin and hydrocodone only product in oral dose form
#   [840 API calls so far]
#   [116/400] Unable to wash laundry -> 286049003 (2P, 1GP, 0C, 10S)
#   [117/400] Entire corticothalamic fibers of posterior limb of internal capsule -> 727132000 (1P, 1GP, 0C, 0S)
#   [860 API calls so far]
#   [118/400] Product containing precisely lidocaine hydrochloride 1 milligram/1 milliliter conventional release solution for injection -> partial match: Lidocaine hydrochloride 1 mg/mL solution for injection
#   [119/400] Congenital absence of uvula -> 25148007 (3P, 4GP, 0C, 9S)
#   [880 API calls so far]
#   [120/400] Streptococcus pyogenes type emm35 -> 442825004 (1P, 3GP, 0C, 99S)
#     [checkpoint] Saved 120 concepts to CSV
#   [121/400] Fracture of mandible involving dental socket -> 263175001 (4P, 7GP, 1C, 178S)
#   [900 API calls so far]
#   [122/400] Foreign body in skin of finger with infection -> 879798000 (3P, 7GP, 5C, 12S)
#   [123/400] Product containing precisely naloxone hydrochloride 400 microgram/1 milliliter conventional release solution for injection -> partial match: Naloxone hydrochloride 400 microgram/mL solution for injection
#   [920 API calls so far]
#   [124/400] Excisional biopsy of lacrimal sac -> 201583003 (4P, 8GP, 0C, 58S)
#   [125/400] Catatonic posturing -> 36734001 (1P, 1GP, 0C, 13S)
#   [126/400] Structure of palmaris brevis muscle -> 18513005 (1P, 2GP, 1C, 4S)
#   [940 API calls so far]
#   [127/400] Butteroil -> 229850009 (1P, 1GP, 0C, 3S)
#   [128/400] Entire ventral posterolateral nucleus of thalamus -> 369171001 (2P, 2GP, 0C, 3S)
#   [129/400] Anomalous pulmonary venous drainage to right atrium -> 37639005 (2P, 3GP, 0C, 25S)
#   [960 API calls so far]
#   [130/400] Caries of cervical margin of tooth -> 716364007 (1P, 6GP, 1C, 21S)
#     [checkpoint] Saved 130 concepts to CSV
#   [131/400] Bursitis of shoulder -> 239961006 (2P, 5GP, 6C, 8S)
#   [132/400] Laboratory oven -> 705221001 (2P, 2GP, 5C, 103S)
#   [980 API calls so far]
#   [133/400] Assessment using physical function intensive care unit test -> 458181000124100 (1P, 1GP, 0C, 100S)
#   [134/400] Oral dyskinesia -> 229694001 (3P, 5GP, 0C, 218S)
#   [1000 API calls so far]
#   [135/400] Family Ranidae -> 107237003 (1P, 1GP, 10C, 14S)
#   [136/400] Acute postthoracotomy pain syndrome -> 444227004 (3P, 4GP, 0C, 2S)
#   [137/400] Trapezius flap -> 180797001 (1P, 1GP, 0C, 43S)
#   [138/400] Fetal movements palpated by healthcare professional -> partial match: Healthcare professional
#   [1020 API calls so far]
#   [139/400] Product containing only sodium thiosulfate in parenteral dose form -> partial match: Sodium thiosulfate only product in parenteral dose form
#   [1040 API calls so far]
#   [140/400] Zamia -> 66502000 (1P, 1GP, 1C, 2S)
#     [checkpoint] Saved 140 concepts to CSV
#   [141/400] Provision of removable artificial eye -> 313124001 (1P, 2GP, 0C, 0S)
#   [142/400] Hypokinesis of myocardium of anterolateral region of left ventricle -> partial match: Entire myocardium of anterolateral region of left ventricle
#   [143/400] CV20 -> 273117001 (1P, 1GP, 0C, 23S)
#   [1060 API calls so far]
#   [144/400] Primary malignant neoplasm of intrathoracic organs -> 93841009 (3P, 5GP, 6C, 59S)
#   [145/400] Salmonella IIIb 38:(k):z54 -> 404375005 (1P, 2GP, 0C, 21S)
#   [1080 API calls so far]
#   [146/400] Purpura simplex -> 277791008 (1P, 3GP, 3C, 17S)
#   [147/400] Arsine poisoning -> 64189001 (2P, 1GP, 1C, 27S)
#   [148/400] Continuous flow apneic ventilation -> 1260411001 (1P, 2GP, 0C, 9S)
#   [149/400] Extension Namespace {1000164} -> 697893004 (1P, 1GP, 0C, 100S)
#   [1100 API calls so far]
#   [150/400] Ear and auditory finding -> 118236001 (1P, 0GP, 4C, 99S)
#     [checkpoint] Saved 150 concepts to CSV
#   [151/400] Antibody to myelin associated glycoprotein -> 117210005 (1P, 1GP, 0C, 16S)
#   [152/400] Genus Cercocebus -> 389143004 (1P, 1GP, 1C, 10S)
#   [1120 API calls so far]
#   [153/400] Urge incontinence due to prolapse of female genital organ -> 762264009 (3P, 4GP, 1C, 112S)
#   [154/400] Streptococcus pyogenes type emm111 -> 443059008 (1P, 3GP, 0C, 99S)
#   [155/400] Partial glossectomy with radical dissection of left half of neck -> 1119432004 (2P, 2GP, 0C, 7S)
#   [1140 API calls so far]
#   [156/400] Paenibacillus doosanensis -> 734244006 (1P, 2GP, 0C, 99S)
#   [157/400] Diapterus auratus -> 53573000 (1P, 2GP, 0C, 9S)
#   [158/400] Ribonucleic acid of Parainfluenza virus 4 -> 707938006 (1P, 1GP, 0C, 5S)
#   [1160 API calls so far]
#   [159/400] Cryptocotyle concava -> 89930003 (1P, 1GP, 0C, 2S)
#   [160/400] Calicivirus gastroenteritis -> 283877002 (2P, 4GP, 2C, 8S)
#     [checkpoint] Saved 160 concepts to CSV
#   [161/400] Acute sensory polyneuropathy -> 1259063005 (2P, 3GP, 0C, 92S)
#   [1180 API calls so far]
#   [162/400] Sabouraud dextrose agar -> 464521000124106 (1P, 1GP, 3C, 28S)
#   [163/400] Urrets-Zavalia syndrome of eye due to and following ocular surgery -> partial match: Ocular hypertension of left eye due to ocular surgery
#   [164/400] Product containing only flortaucipir (18-F) in parenteral dose form -> partial match: Flortaucipir (18-F) only product in parenteral dose form
#   [1200 API calls so far]
#   [165/400] Structure of skin of left knee -> 726002000 (3P, 7GP, 1C, 18S)
#   [166/400] Grafting of auricle of ear -> 23235002 (2P, 4GP, 0C, 117S)
#   [1220 API calls so far]
#   [167/400] Closed fracture of fifth metatarsal bone of right foot -> 10930121000119109 (2P, 2GP, 1C, 8S)
#   [168/400] Ultrasonic wave -> 51797001 (1P, 1GP, 0C, 4S)
#   [169/400] Accessory mobilization of the cervical spine -> 229410002 (1P, 3GP, 0C, 1S)
#   [1240 API calls so far]
#   [170/400] Scilla nonscripta -> 61818004 (1P, 1GP, 0C, 2S)
#     [checkpoint] Saved 170 concepts to CSV
#   [171/400] Product containing precisely mepacrine hydrochloride 100 milligram/1 each conventional release oral tablet -> partial match: Tramadol hydrochloride 100 mg prolonged-release oral tablet
#   [172/400] Antibiotic sensitivity, fungus -> 359819009 (1P, 1GP, 0C, 82S)
#   [1260 API calls so far]
#   [173/400] Alcohol, methyl measurement -> 57582005 (1P, 1GP, 1C, 39S)
#   [174/400] Structure of bursa of thumb -> 769938005 (2P, 5GP, 1C, 11S)
#   [1280 API calls so far]
#   [175/400] History and physical examination, sports participation -> 103736005 (2P, 3GP, 6C, 47S)
#   [176/400] Haemophilus felis -> 432176001 (1P, 2GP, 0C, 16S)
#   [177/400] Cholylglycine measurement -> 13046005 (1P, 1GP, 0C, 56S)
#   [178/400] Radiation half-value thickness -> 228782005 (1P, 1GP, 0C, 0S)
#   [1300 API calls so far]
#   [179/400] Entire embryo at stage 15 -> 784038003 (2P, 2GP, 0C, 24S)
#   [180/400] Product containing only mecobalamin -> partial match: Mecobalamin only product
#     [checkpoint] Saved 180 concepts to CSV
#   [181/400] Genus Lophodytes -> 396816008 (1P, 1GP, 1C, 14S)
#   [1320 API calls so far]
#   [182/400] Mycoplasma hyopneumoniae -> 81326007 (1P, 2GP, 0C, 99S)
#   [183/400] Fetal chromosomal abnormality -> partial match: Fetal chromosomal abnormality screening
#   [1340 API calls so far]
#   [184/400] History of cancer metastatic to bone -> 1099291000119102 (2P, 2GP, 0C, 8S)
#   [185/400] Orthopedic fixation plate, non-bioabsorbable, non-sterile -> 713841008 (1P, 1GP, 0C, 0S)
#   [186/400] Neoplasm of isthmus of uterus -> 126911008 (1P, 2GP, 5C, 10S)
#   [187/400] Urethrotome -> 464369005 (1P, 1GP, 0C, 14S)
#   [1360 API calls so far]
#   [188/400] Death by immolation -> 5062002 (1P, 1GP, 0C, 0S)
#   [189/400] Skin of part of back -> 281722005 (1P, 2GP, 2C, 2S)
#   [190/400] Croton oil -> 54588003 (2P, 2GP, 0C, 20S)
#     [checkpoint] Saved 190 concepts to CSV
#   [1380 API calls so far]
#   [191/400] Associated_finding_filler -> 363666001 (1P, 1GP, 0C, 33S)
#   [192/400] Lyssavirus aravan -> 450620008 (1P, 1GP, 0C, 10S)
#   [193/400] Main spoken language Esperanto -> 698896005 (1P, 1GP, 0C, 99S)
#   [1400 API calls so far]
#   [194/400] Unable to prepare food hygienically -> 286533007 (2P, 1GP, 0C, 16S)
#   [195/400] Proximal radioulnar joint structure -> 20903007 (5P, 6GP, 3C, 69S)
#   [1420 API calls so far]
#   [196/400] Early onset cerebellar ataxia -> 230227009 (1P, 2GP, 12C, 60S)
#   [197/400] Cresylglycidyl ether -> 256090005 (2P, 2GP, 0C, 143S)
#   [198/400] Etheostoma zoniferum -> 90778000 (1P, 2GP, 0C, 99S)
#   [1440 API calls so far]
#   [199/400] Plasma thawing unit -> 463951000 (1P, 1GP, 0C, 13S)
#   [200/400] Fracture of coccyx -> 125871005 (4P, 12GP, 2C, 45S)
#     [checkpoint] Saved 200 concepts to CSV
#   [1460 API calls so far]
#   [201/400] 3 o'clock position on mammogram -> 129774003 (1P, 1GP, 0C, 15S)
#   [202/400] Old posterior cruciate ligament disruption -> 202111003 (3P, 6GP, 0C, 14S)
#   [203/400] Anxious avoidant attachment -> 304871006 (2P, 1GP, 0C, 4S)
#   [1480 API calls so far]
#   [204/400] Inflammation of left iliohypogastric nerve -> 292271000119101 (1P, 2GP, 1C, 1S)
#   [205/400] Re-excision of breast for clearance of tumor margins -> 395165008 (2P, 4GP, 0C, 38S)
#   [1500 API calls so far]
#   [206/400] Diamond dental laboratory bur -> 468560000 (2P, 2GP, 0C, 7S)
#   [207/400] Family Fuselloviridae -> 424194001 (1P, 1GP, 1C, 14S)
#   [208/400] Occlusion of vein of corpus cavernosum of penis -> partial match: Corpus cavernosum of penis
#   [1520 API calls so far]
#   [209/400] Autosomal dominant intermediate Charcot-Marie-Tooth disease type C -> 765746008 (2P, 2GP, 0C, 137S)
#   [210/400] Hemoglobin Volga -> 75384008 (1P, 1GP, 0C, 100S)
#     [checkpoint] Saved 210 concepts to CSV
#   [211/400] Punctate outer retinal toxoplasmosis -> 415218004 (1P, 2GP, 0C, 4S)
#   [1540 API calls so far]
#   [212/400] Congenital talipes calcaneovalgus -> 205083002 (3P, 4GP, 0C, 27S)
#   [213/400] Recurrent acute streptococcal tonsillitis -> 10629231000119109 (4P, 8GP, 0C, 6S)
#   [1560 API calls so far]
#   [214/400] Jaeger type 10 -> 260249006 (1P, 1GP, 0C, 30S)
#   [215/400] Myofascial pain syndrome of lower back -> 279041008 (5P, 11GP, 0C, 202S)
#   [1580 API calls so far]
#   [216/400] Spine dislocation due to birth trauma -> 206221000 (4P, 7GP, 1C, 54S)
#   [217/400] Netta rufina -> 63601007 (1P, 1GP, 0C, 1S)
#   [1600 API calls so far]
#   [218/400] Congenital abnormality of systemic vein -> 448065006 (2P, 3GP, 14C, 118S)
#   [219/400] Stachybotrys chartarum -> 418469000 (1P, 3GP, 0C, 2S)
#   [220/400] Fracture of phalanx of finger of left hand -> 1303399008 (3P, 7GP, 4C, 52S)
#     [checkpoint] Saved 220 concepts to CSV
#   [1620 API calls so far]
#   [221/400] Astroscopus y-graecum -> 7578009 (1P, 2GP, 0C, 4S)
#   [222/400] Vaccine product containing only Clostridium tetani and Human poliovirus antigens -> partial match: Clostridium tetani and Human poliovirus antigens only vaccine product
#   [1640 API calls so far]
#   [223/400] Single photon emission computed tomography system -> 717313001 (1P, 1GP, 0C, 100S)
#   [224/400] Measurement of Influenza A virus antibody and Influenza B virus antibody -> 117817000 (3P, 3GP, 0C, 49S)
#   [1660 API calls so far]
#   [225/400] Chronic radiation nephritis -> 236525007 (3P, 6GP, 0C, 148S)
#   [226/400] Giant retinal tear -> 232004004 (3P, 10GP, 2C, 16S)
#   [227/400] Structure of lateral surface of upper arm -> 34894009 (2P, 2GP, 3C, 6S)
#   [1680 API calls so far]
#   [228/400] Family Echinorhynchidae -> 106753006 (1P, 1GP, 2C, 4S)
#   [229/400] Embolectomy with catheter of celiac artery by abdominal incision -> 15905001 (5P, 8GP, 0C, 220S)
#   [1700 API calls so far]
#   [230/400] Entire zygomatic arch -> 272682006 (1P, 1GP, 0C, 4S)
#     [checkpoint] Saved 230 concepts to CSV
#   [231/400] Application of hot water bottle -> 37353002 (1P, 1GP, 0C, 65S)
#   [232/400] Tilmicosin -> 792797003 (1P, 2GP, 0C, 1S)
#   [1720 API calls so far]
#   [233/400] Hypothalamic releasing factor -> 734789006 (1P, 1GP, 0C, 11S)
#   [234/400] Perioral numbness -> 102601005 (2P, 4GP, 0C, 22S)
#   [235/400] Electron microscopy study, transmission, examination and report -> 58145007 (1P, 1GP, 0C, 12S)
#   [1740 API calls so far]
#   [236/400] Structure of hypothalamicohypophyseal tract -> 88964007 (1P, 3GP, 3C, 7S)
#   [237/400] Incision and exploration of tunica vaginalis -> 40032003 (2P, 4GP, 0C, 1S)
#   [238/400] Injury of nasopharynx -> 285671001 (3P, 7GP, 1C, 69S)
#   [1760 API calls so far]
#   [239/400] Grafting of fascia to tarsal cartilage -> 90871000 (2P, 3GP, 0C, 8S)
#   [240/400] Accidental ingestion of spurge olive berries -> 242340008 (1P, 2GP, 0C, 38S)
#     [checkpoint] Saved 240 concepts to CSV
#   [241/400] Stimulus response inventory -> 273838009 (1P, 1GP, 0C, 100S)
#   [1780 API calls so far]
#   [242/400] Fall risk assessment declined -> 720832001 (1P, 1GP, 0C, 5S)
#   [243/400] Vegetable suet -> 229858002 (1P, 1GP, 0C, 1S)
#   [1800 API calls so far]
#   [244/400] Flexion deformity of joint of right ankle -> 15935301000119104 (3P, 5GP, 1C, 49S)
#   [245/400] Delayed allogeneic transplantation, living donor -> 50053001 (1P, 1GP, 0C, 25S)
#   [246/400] Finding of knee joint color -> 366601002 (2P, 3GP, 1C, 81S)
#   [1820 API calls so far]
#   [247/400] Entire sinus venosus of fetus -> 341180007 (1P, 2GP, 0C, 0S)
#   [248/400] Blood (white blood cell) screen for GM1 gangliosidosis -> 391472005 (1P, 1GP, 0C, 13S)
#   [249/400] Cystic testicular dysplasia -> 109560004 (3P, 6GP, 0C, 17S)
#   [1840 API calls so far]
#   [250/400] No active range of shoulder circumduction -> 298847009 (3P, 3GP, 0C, 77S)
#     [checkpoint] Saved 250 concepts to CSV
#   [251/400] Product containing precisely promethazine hydrochloride 25 milligram/1 each conventional release oral tablet -> partial match: Promethazine hydrochloride 25 mg oral tablet
#   [252/400] Spotted creeper -> 25921007 (1P, 1GP, 0C, 11S)
#   [1860 API calls so far]
#   [253/400] Chilomastix intestinalis -> 86121009 (1P, 1GP, 0C, 6S)
#   [254/400] Extraprostatic extension of tumor present, non-focal -> 420387003 (1P, 1GP, 0C, 3S)
#   [255/400] Arteriovenous graft rupture -> 280975005 (3P, 5GP, 0C, 139S)
#   [1880 API calls so far]
#   [256/400] Structure of superficial anterior cervical lymph node -> 168557005 (2P, 2GP, 1C, 5S)
#   [257/400] Myelodysplastic syndrome with excess blasts-1 -> 415283002 (1P, 1GP, 0C, 1S)
#   [1900 API calls so far]
#   [258/400] Administration of substance via buccal route -> 431952007 (2P, 2GP, 0C, 161S)
#   [259/400] Product containing only bendroflumethiazide and potassium chloride -> partial match: Bendroflumethiazide and potassium chloride only product
#   [260/400] Transmission-based precautions -> 409583003 (1P, 2GP, 3C, 8S)
#     [checkpoint] Saved 260 concepts to CSV
#   [1920 API calls so far]
#   [261/400] Tooth disorder -> 234947003 (3P, 4GP, 49C, 80S)
#   [262/400] Physical -> 19388002 (1P, 1GP, 0C, 28S)
#   [263/400] Dislocation of ear ossicles -> 87040007 (2P, 3GP, 4C, 29S)
#   [1940 API calls so far]
#   [264/400] Fracture dislocation of symphysis pubis -> 263067005 (3P, 8GP, 0C, 25S)
#   [265/400] Tache noire of sclera of left eye -> 470751000124107 (2P, 7GP, 1C, 16S)
#   [266/400] Volatile inhalant dependence, episodic -> partial match: Inhalant dependence, episodic
#   [1960 API calls so far]
#   [267/400] Decreased N-3 fatty acid diet -> 1142129004 (1P, 2GP, 3C, 4S)
#   [268/400] Carbapenemase-producing Lelliottia amnigena -> 1112101000112106 (2P, 3GP, 0C, 10S)
#   [1980 API calls so far]
#   [269/400] Polychromatophilic erythroblast -> 16779009 (1P, 1GP, 0C, 2S)
#   [270/400] Fuller's earth dust -> 426368004 (1P, 2GP, 0C, 0S)
#     [checkpoint] Saved 270 concepts to CSV
#   [271/400] Stress fracture of sacrum -> 441881007 (3P, 5GP, 2C, 9S)
#   [2000 API calls so far]
#   [272/400] Poor self-esteem -> 162220005 (1P, 1GP, 0C, 4S)
#   [273/400] Bathrocephaly -> 450808003 (1P, 1GP, 0C, 26S)
#   [274/400] Snuff user -> 228494002 (2P, 2GP, 0C, 3S)
#   [2020 API calls so far]
#   [275/400] Generalized onset motor epileptic seizure -> 1208966001 (2P, 1GP, 8C, 10S)
#   [276/400] Allergy treatment changed -> 170841002 (1P, 1GP, 0C, 26S)
#   [2040 API calls so far]
#   [277/400] Erosion of pacemaker pocket due to and following implantation of cardiac pacemaker -> 762249009 (8P, 10GP, 0C, 435S)
#   [278/400] Head lifting exercise -> 229151005 (1P, 2GP, 0C, 4S)
#   [279/400] Entire corpus penis -> 362271005 (1P, 1GP, 0C, 7S)
#   [2060 API calls so far]
#   [280/400] Oligopus diagrammus -> 44573000 (1P, 2GP, 0C, 6S)
#     [checkpoint] Saved 280 concepts to CSV
#   [281/400] Deficiency of ribose-5-phosphate isomerase -> 124667004 (1P, 1GP, 0C, 100S)
#   [282/400] Progestogen overdose -> 296878004 (2P, 3GP, 2C, 4S)
#   [2080 API calls so far]
#   [283/400] Cartilage graft - prominent ear -> 287409005 (2P, 3GP, 0C, 30S)
#   [284/400] Borrelia theileri -> 89068003 (1P, 1GP, 0C, 41S)
#   [2100 API calls so far]
#   [285/400] Mood disorder with mixed depressive and manic symptoms caused by volatile inhalant -> 762340006 (3P, 4GP, 0C, 19S)
#   [286/400] Degloving injury buttock -> 210422006 (2P, 5GP, 0C, 17S)
#   [287/400] Attachment of bone anchored hearing prosthesis -> 426733001 (2P, 2GP, 1C, 135S)
#   [2120 API calls so far]
#   [288/400] Air traffic controller -> 10975003 (2P, 3GP, 2C, 13S)
#   [289/400] Entire intervertebral symphysis between T2 and T3 -> 244520003 (2P, 3GP, 0C, 13S)
#   [290/400] Protostrongylus brevispiculum -> 86729004 (1P, 1GP, 0C, 12S)
#     [checkpoint] Saved 290 concepts to CSV
#   [2140 API calls so far]
#   [291/400] Vasomotor rhinitis -> 8229003 (2P, 4GP, 0C, 26S)
#   [292/400] Able to open and close mouth -> 285454007 (2P, 2GP, 2C, 7S)
#   [2160 API calls so far]
#   [293/400] Pseudoxanthomonas helianthi -> 738498001 (1P, 1GP, 0C, 8S)
#   [294/400] Repair of ventral hernia using graft -> 737067005 (1P, 3GP, 1C, 15S)
#   [295/400] Assessment using Short Form of the Informant Questionnaire on Cognitive Decline in the Elderly -> 459681000124104 (1P, 1GP, 0C, 100S)
#   [296/400] Acute inflammation -> 4532008 (1P, 1GP, 20C, 4S)
#   [2180 API calls so far]
#   [297/400] Autosomal recessive hereditary spastic paraplegia -> 1187279003 (2P, 5GP, 53C, 105S)
#   [298/400] Octomitus -> 39618008 (1P, 1GP, 0C, 3S)
#   [2200 API calls so far]
#   [299/400] Toxoplasma tubulointerstitial nephropathy -> 1092831000119109 (5P, 8GP, 0C, 142S)
#   [300/400] Notropis harperi -> 8575005 (1P, 2GP, 0C, 99S)
#     [checkpoint] Saved 300 concepts to CSV
#   [301/400] History of toxoplasmosis -> 143591000119101 (1P, 1GP, 0C, 1S)
#   [2220 API calls so far]
#   [302/400] Blood group antigen Sk^a^ -> 89041003 (1P, 1GP, 0C, 99S)
#   [303/400] Wedge excision of skin of nail fold -> 65578005 (3P, 5GP, 0C, 5S)
#   [304/400] Finding of difference in location compared to previous radiologic examination -> 442726008 (1P, 1GP, 0C, 14S)
#   [2240 API calls so far]
#   [305/400] Christo Inventory for Substance-misuse Services total score -> 761872001 (1P, 1GP, 0C, 99S)
#   [306/400] Aspidites melanocephalus -> 36903008 (1P, 1GP, 0C, 8S)
#   [307/400] General medical self-referral -> 183688007 (2P, 3GP, 0C, 18S)
#   [2260 API calls so far]
#   [308/400] Artery of extremity transposition -> 119816000 (2P, 5GP, 0C, 48S)
#   [309/400] Occlusion of left central retinal artery -> 341801000119101 (2P, 6GP, 1C, 7S)
#   [310/400] Nutrient absorption inhibitor -> 705506006 (1P, 1GP, 1C, 41S)
#     [checkpoint] Saved 310 concepts to CSV
#   [2280 API calls so far]
#   [311/400] Laceration of thigh without foreign body -> 735836006 (1P, 2GP, 0C, 7S)
#   [312/400] Eimeria magna -> 80007001 (1P, 1GP, 0C, 99S)
#   [2300 API calls so far]
#   [313/400] Enterocolic fistula -> 111356006 (3P, 4GP, 3C, 17S)
#   [314/400] Rehabilitation care plan -> 736055001 (1P, 1GP, 2C, 77S)
#   [315/400] Blood group antigen Naz -> 82239006 (1P, 2GP, 0C, 99S)
#   [2320 API calls so far]
#   [316/400] Bilastine -> 697973006 (2P, 2GP, 0C, 105S)
#   [317/400] Appearance of oral mucosa -> 364117009 (1P, 2GP, 2C, 1S)
#   [318/400] Superior closed dislocation -> 85016000 (1P, 1GP, 0C, 13S)
#   [319/400] Khoshamian -> 261876007 (1P, 1GP, 0C, 58S)
#   [2340 API calls so far]
#   [320/400] Urine codeine measurement -> 312464001 (2P, 2GP, 1C, 15S)
#     [checkpoint] Saved 320 concepts to CSV
#   [321/400] Computed tomography of thigh for radiotherapy planning -> 715248007 (2P, 3GP, 0C, 3S)
#   [2360 API calls so far]
#   [322/400] Application of long leg cast -> 63097004 (2P, 3GP, 2C, 73S)
#   [323/400] Acute duodenitis -> 715834004 (3P, 5GP, 0C, 174S)
#   [324/400] Nuclear medicine system table, powered -> 463942008 (1P, 1GP, 0C, 40S)
#   [2380 API calls so far]
#   [325/400] Local tumor spread -> 255127006 (1P, 1GP, 0C, 52S)
#   [326/400] Family Kogiidae -> partial match: Family
#   [327/400] Able to transfer from wheelchair to chair -> 715086007 (1P, 2GP, 0C, 8S)
#   [2400 API calls so far]
#   [328/400] Selectron therapy -> 395074007 (1P, 2GP, 0C, 32S)
#   [329/400] Structure of superficial part of superior levator palpebrae muscle -> 39219007 (1P, 2GP, 1C, 2S)
#   [330/400] Entire left wall of urinary bladder -> 54217004 (2P, 3GP, 0C, 1S)
#     [checkpoint] Saved 330 concepts to CSV
#   [2420 API calls so far]
#   [331/400] Urine specimen care assessment -> 385841005 (1P, 1GP, 0C, 3S)
#   [332/400] Structure of intervertebral disc of sacral vertebra -> 110533007 (2P, 3GP, 1C, 12S)
#   [333/400] Amino acids peritoneal dialysis solution -> 326370009 (1P, 1GP, 0C, 2S)
#   [2440 API calls so far]
#   [334/400] Family Caryophyllaceae -> 107546005 (3P, 3GP, 3C, 51S)
#   [335/400] Umbilical catheter submitted as specimen -> 472920001 (1P, 1GP, 1C, 3S)
#   [336/400] Product containing precisely desmopressin acetate 100 microgram/1 milliliter conventional release nasal solution -> partial match: Desmopressin acetate 100 microgram/mL nasal solution
#   [2460 API calls so far]
#   [337/400] Syncytial cell -> 72263005 (1P, 1GP, 0C, 99S)
#   [338/400] Extension Namespace {1000085} -> 440023001 (1P, 1GP, 0C, 100S)
#   [2480 API calls so far]
#   [339/400] Congenital absence of frontal bone -> 91885001 (3P, 5GP, 0C, 23S)
#   [340/400] Incision and exploration of rectum -> 48630009 (3P, 7GP, 0C, 5S)
#     [checkpoint] Saved 340 concepts to CSV
#   [341/400] Needle catheter -> 713943007 (1P, 1GP, 0C, 87S)
#   [2500 API calls so far]
#   [342/400] Percutaneous transluminal embolization of femoral artery -> 175719009 (2P, 2GP, 0C, 33S)
#   [343/400] Stung by cone shell -> 242599009 (1P, 2GP, 0C, 9S)
#   [344/400] Head artery injection -> 119786004 (2P, 4GP, 2C, 31S)
#   [2520 API calls so far]
#   [345/400] True insight, function -> 51187000 (1P, 2GP, 0C, 2S)
#   [346/400] Disorder due to and following injury of muscle and tendon of upper limb -> 210960009 (1P, 2GP, 0C, 5S)
#   [347/400] Entire left foot -> 239919000 (2P, 3GP, 0C, 12S)
#   [2540 API calls so far]
#   [348/400] Recurrent erosion of cornea of left eye -> 338351000119101 (2P, 3GP, 1C, 3S)
#   [349/400] Excision of salivary gland -> 71735005 (2P, 4GP, 7C, 72S)
#   [2560 API calls so far]
#   [350/400] Adverse effect of prosthetic device -> 95869003 (3P, 2GP, 0C, 168S)
#     [checkpoint] Saved 350 concepts to CSV
#   [351/400] Total excision of meningioma -> 446307000 (2P, 5GP, 0C, 24S)
#   [352/400] Cote d'Ivoire -> 223561000 (1P, 1GP, 0C, 17S)
#   [2580 API calls so far]
#   [353/400] Fluoroscopic venography of hepatic vein with contrast and insertion of stent graft -> 431602001 (1P, 3GP, 0C, 0S)
#   [354/400] Amyloid deposition -> 68790008 (1P, 1GP, 4C, 29S)
#   [355/400] Measurement of serum thyroid stimulating hormone -> 313440008 (1P, 1GP, 5C, 4S)
#   [2600 API calls so far]
#   [356/400] Excessive secretin secretion -> 237582003 (1P, 4GP, 0C, 0S)
#   [357/400] Cataract lens fragments in vitreous of left eye due to and following cataract surgery -> 340021000119108 (2P, 5GP, 1C, 3S)
#   [358/400] Toe joint crepitus -> 299634006 (2P, 3GP, 2C, 55S)
#   [2620 API calls so far]
#   [359/400] Gynecological operating table -> 706411000 (2P, 2GP, 4C, 104S)
#   [360/400] Product containing hydrolase inhibitor -> partial match: Hydrolase inhibitor-containing product
#     [checkpoint] Saved 360 concepts to CSV
#   [2640 API calls so far]
#   [361/400] Edoxaban tosylate -> 1162278009 (2P, 3GP, 0C, 41S)
#   [362/400] Deep dog bite -> 262571007 (2P, 2GP, 0C, 7S)
#   [363/400] Family Kinosternidae -> 107244007 (1P, 1GP, 1C, 13S)
#   [364/400] Substance with sodium/potassium adenosine triphosphatase enzyme inhibitor mechanism of action -> partial match: Substance with beta-lactamase inhibitor mechanism of action
#   [2660 API calls so far]
#   [365/400] Delayed suture of tendon -> 12492009 (2P, 4GP, 1C, 19S)
#   [366/400] Specimen source -> 703065002 (1P, 1GP, 0C, 11S)
#   [2680 API calls so far]
#   [367/400] Microinvasive carcinoma -> 264550001 (1P, 1GP, 0C, 64S)
#   [368/400] Abdominal reflex delayed -> 299855006 (1P, 2GP, 0C, 6S)
#   [369/400] Product containing only phenazopyridine -> partial match: Phenazopyridine only product
#   [2700 API calls so far]
#   [370/400] Incision and drainage of hematoma -> 443385002 (1P, 2GP, 7C, 37S)
#     [checkpoint] Saved 370 concepts to CSV
#   [371/400] Skin structure of infratemporal region -> 40207008 (3P, 5GP, 1C, 11S)
#   [372/400] Soft tissue lesion of foot region -> 240025005 (2P, 3GP, 59C, 179S)
#   [2720 API calls so far]
#   [373/400] Arthroscopic release of capsule of hip joint -> 449362005 (2P, 6GP, 0C, 106S)
#   [374/400] Traumatic joint hemarthrosis -> 239775007 (3P, 4GP, 3C, 79S)
#   [2740 API calls so far]
#   [375/400] Long QT syndrome caused by drug -> 715971003 (1P, 1GP, 0C, 0S)
#   [376/400] Neocoger mucronatus -> 25496003 (1P, 2GP, 0C, 1S)
#   [377/400] Product containing bismuth subsalicylate and metronidazole and tetracycline -> partial match: Bismuth subsalicylate- and metronidazole- and tetracycline-containing product
#   [2760 API calls so far]
#   [378/400] Pulmonary artery pressure -> 250767002 (1P, 1GP, 3C, 0S)
#   [379/400] Arthroscopy of shoulder with complete synovectomy -> 77341008 (2P, 5GP, 0C, 19S)
#   [380/400] beta-Aminoisobutyrate measurement -> 104543006 (1P, 1GP, 2C, 49S)
#     [checkpoint] Saved 380 concepts to CSV
#   [2780 API calls so far]
#   [381/400] Injury of thymus gland -> 27158007 (4P, 8GP, 2C, 31S)
#   [382/400] Finding related to ability to balance -> 366614001 (1P, 1GP, 9C, 9S)
#   [2800 API calls so far]
#   [383/400] Porphyrins, quantitation and fractionation, urine -> 104887006 (2P, 3GP, 0C, 123S)
#   [384/400] Trichostrongylus retortaeformis -> 28100005 (1P, 1GP, 0C, 21S)
#   [385/400] Extrinsic motivation -> 112076007 (1P, 1GP, 0C, 9S)
#   [2820 API calls so far]
#   [386/400] Duodenal candidosis -> 840506008 (3P, 7GP, 0C, 56S)
#   [387/400] Take impression for lower removable orthodontic appliance -> 234756004 (1P, 1GP, 0C, 1S)
#   [2840 API calls so far]
#   [388/400] Primary basal cell carcinoma of skin of left foot -> 428487561000119102 (3P, 9GP, 0C, 12S)
#   [389/400] Rigid ankle-foot orthosis -> 183160000 (1P, 1GP, 0C, 30S)
#   [390/400] Closed fracture thumb proximal phalanx, head -> 208438007 (3P, 4GP, 0C, 93S)
#     [checkpoint] Saved 390 concepts to CSV
#   [2860 API calls so far]
#   [391/400] Acute suppuration of maxillary sinus -> 23884004 (2P, 2GP, 0C, 4S)
#   [392/400] Dodecenoyl-coenzyme A delta-isomerase -> 76907000 (2P, 2GP, 0C, 189S)
#   [393/400] Entire lymphatic vessel of orbit -> 1197036005 (1P, 2GP, 0C, 1S)
#   [2880 API calls so far]
#   [394/400] Blood group antigen Wallin -> 71415008 (1P, 2GP, 0C, 99S)
#   [395/400] Corynebacterium species not Corynebacterium jeikeium -> 413930001 (1P, 1GP, 0C, 99S)
#   [396/400] Nocardioides terrae -> 25961000181103 (1P, 3GP, 0C, 65S)
#   [397/400] Lactobacillus rhamnosus GG -> 412234005 (1P, 1GP, 0C, 3S)
#   [2900 API calls so far]
#   [398/400] Pain of breast -> 53430007 (2P, 4GP, 10C, 30S)
#   [399/400] Structure of left cochlear -> 772064001 (2P, 3GP, 1C, 6S)
#   [2920 API calls so far]
#   [400/400] Decreased active range of hip flexion -> 299243005 (3P, 3GP, 0C, 77S)
#     [checkpoint] Saved 400 concepts to CSV
#
# Done. Total API calls: 2925
# Found: 370
# Partial match: 30
# Replaced: 0
# Not found (no replacement): 0

# %% [markdown]
# ## Save Results

# %%
# ============================================================
# Save ground truth CSV
# ============================================================
if gt_rows:
    gt_df = pd.DataFrame(gt_rows)
    gt_df = gt_df[[
        "timestamp", "concept_term", "snomed_id",
        "fsn", "semantic_tag", "definition_status",
        "parents", "grandparents", "children", "siblings",
    ]]
    gt_df.to_csv(GT_OUT, index=False)
    print(f"Ground truth saved: {GT_OUT} ({len(gt_df)} concepts)")
else:
    print("WARNING: No ground truth rows to save!")

# ============================================================
# Save validated concepts CSV
# ============================================================
if validation_rows:
    val_df = pd.DataFrame(validation_rows)
    val_df = val_df[["concept_term", "original_term", "snomed_id", "status"]]
    val_df.to_csv(VALIDATED_CONCEPTS_OUT, index=False)
    print(f"Validated concepts saved: {VALIDATED_CONCEPTS_OUT} ({len(val_df)} concepts)")
else:
    print("WARNING: No validated concepts to save!")

# ============================================================
# Summary (from full validation_rows so resume runs are included)
# ============================================================
_replaced = [(r["original_term"], r["concept_term"]) for r in validation_rows if r.get("status") == "replaced"]
_not_found = [r["original_term"] for r in validation_rows if r.get("status") == "not_found"]
if _replaced:
    print("\nReplaced concepts:")
    for orig, repl in _replaced:
        print(f"  {orig} -> {repl}")

if _not_found:
    print("\nCould not find or replace:")
    for t in _not_found:
        print(f"  {t}")

if not _replaced and not _not_found:
    pass  # no replaced/not_found to show

print("\n" + "=" * 80)
print("Step 1 complete. Ground truth is shared by all LLM folders.")
print("Now run step2_llm_queries.ipynb in each testing_* folder.")
print("=" * 80)
# Out:
# Ground truth saved: /Users/narenkhatwani/Documents/GitHub/llm-as-ontology-server/output/ground_truth/ground_truth.csv (400 concepts)
# Validated concepts saved: /Users/narenkhatwani/Documents/GitHub/llm-as-ontology-server/output/ground_truth/validated_concepts.csv (400 concepts)
#
# ================================================================================
# Step 1 complete. Ground truth is shared by all LLM folders.
# Now run step2_llm_queries.ipynb in each testing_* folder.
# ================================================================================
